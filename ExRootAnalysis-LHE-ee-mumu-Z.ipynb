# %%
import sys
sys.path.insert(0,'/eos/home-a/antoniov/SWAN_projects/env/uproot-py39/lib/python3.9/site-packages')
print ( sys.path )
import uproot
import awkward as ak
import numpy as np
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
mpl.rcParams.update(
    {'font.size': 18,
     'font.family': 'sans-serif',
     'legend.fontsize': 14,
     'axes.labelsize': 22,
     'axes.labelpad': 8.0,
     'xtick.labelsize': 14,
     'ytick.labelsize': 14
    }
    )
# print ( mpl.rcParams )
# Out:
# ['/eos/home-a/antoniov/SWAN_projects/env/uproot-py39/lib/python3.9/site-packages', '/cvmfs/sft.cern.ch/lcg/releases/condor/8.9.11-e1651/x86_64-centos7-gcc11-opt/lib/python3', '/cvmfs/sft.cern.ch/lcg/views/LCG_102swan/x86_64-centos7-gcc11-opt/lib/python3.9/site-packages/itk', '/cvmfs/sft.cern.ch/lcg/views/LCG_102swan/x86_64-centos7-gcc11-opt/python', '/cvmfs/sft.cern.ch/lcg/views/LCG_102swan/x86_64-centos7-gcc11-opt/lib', '', '/cvmfs/sft.cern.ch/lcg/views/LCG_102swan/x86_64-centos7-gcc11-opt/lib/python3.9/site-packages', '/cvmfs/sft.cern.ch/lcg/releases/Python/3.9.6-b0f98/x86_64-centos7-gcc8-opt/lib/python39.zip', '/cvmfs/sft.cern.ch/lcg/releases/Python/3.9.6-b0f98/x86_64-centos7-gcc8-opt/lib/python3.9', '/cvmfs/sft.cern.ch/lcg/releases/Python/3.9.6-b0f98/x86_64-centos7-gcc8-opt/lib/python3.9/lib-dynload', '/eos/home-a/antoniov/SWAN_projects/env/uproot-py39/lib/python3.9/site-packages', '/cvmfs/sft.cern.ch/lcg/views/LCG_102swan/x86_64-centos7-gcc11-opt/lib/python3.9/site-packages/IPython/extensions', '/scratch/antoniov/.ipython']

# %%
from read_lhe_uproot import *

# %%
dir__ = 'SM_ee_mumu_80GeV'
path__ = 'data/{}/run_01/unweighted_events.root'.format( dir__ )
df = read_lhe_uproot( path__ )
df.head(50)
# Out:
# ['Event', 'Event/Event.fUniqueID', 'Event/Event.fBits', 'Event/Event.Number', 'Event/Event.Nparticles', 'Event/Event.ProcessID', 'Event/Event.Weight', 'Event/Event.ScalePDF', 'Event/Event.CouplingQED', 'Event/Event.CouplingQCD', 'Event_size', 'Rwgt', 'Rwgt/Rwgt.fUniqueID', 'Rwgt/Rwgt.fBits', 'Rwgt/Rwgt.Weight', 'Rwgt_size', 'Particle', 'Particle/Particle.fUniqueID', 'Particle/Particle.fBits', 'Particle/Particle.PID', 'Particle/Particle.Status', 'Particle/Particle.Mother1', 'Particle/Particle.Mother2', 'Particle/Particle.ColorLine1', 'Particle/Particle.ColorLine2', 'Particle/Particle.Px', 'Particle/Particle.Py', 'Particle/Particle.Pz', 'Particle/Particle.E', 'Particle/Particle.M', 'Particle/Particle.PT', 'Particle/Particle.Eta', 'Particle/Particle.Phi', 'Particle/Particle.Rapidity', 'Particle/Particle.LifeTime', 'Particle/Particle.Spin', 'Particle_size']
# Number of events: 100000
#        PID  Status  Mother1  Mother2  ColorLine1  ColorLine2         Px  \
# event
# 1      -11      -1       -1       -1           0           0   0.000000
# 1       11      -1       -1       -1           0           0  -0.000000
# 1      -13       1        0        1           0           0  -7.157922
# 1       13       1        0        1           0           0   7.157922
# 2      -11      -1       -1       -1           0           0   0.000000
# 7       -0.757616       0.0   1.0      7
# 7        0.757616       0.0  -1.0      7
# 8      999.900000       0.0   1.0      8
# 8     -999.900000       0.0  -1.0      8
# 8      999.900000       0.0   0.0      8
# 8       -0.493471       0.0  -1.0      8
# 8        0.493471       0.0   1.0      8
# 9      999.900000       0.0   1.0      9
# 9     -999.900000       0.0  -1.0      9
# 9      999.900000       0.0   0.0      9
# 9       -1.652794       0.0  -1.0      9
# 9        1.652794       0.0   1.0      9
# 10     999.900000       0.0  -1.0     10
# 10    -999.900000       0.0   1.0     10
# 10     999.900000       0.0   0.0     10
# 10      -0.816747       0.0   1.0     10
# 10       0.816747       0.0  -1.0     10
# 11     999.900000       0.0   1.0     11
# 11    -999.900000       0.0  -1.0     11
# 11     999.900000       0.0   0.0     11
# 11      -0.257374       0.0  -1.0     11

# %%
def process_select_data( df ):
    df__ = df
    df__[ 'cos_theta' ] = df__.Pz / np.sqrt( df__.Pz ** 2 + df__.PT ** 2 )
    selection__ = ( ( df__.Status == 1 ) & ( df__.PID == 13 ) )
    # selection = ( ( df.Status == 1 ) & ( df.PID == -13 ) )
    # selection = ( ( df.Status == 1 ) & ( df.PID == 11 ) )
    df_sel__ = df__[ selection__ ]
    return df_sel__

# %%
df_sel = process_select_data( df )
df_sel
# Out:
#         PID  Status  Mother1  Mother2  ColorLine1  ColorLine2         Px  \
# event
# 1        13       1        0        1           0           0   7.157922
# 2        13       1        0        1           0           0  -7.475701
# 3        13       1        0        1           0           0  28.847345
# 4        13       1        0        1           0           0  -4.574011
# 5        13       1        2        2           0           0  33.218926
# ...     ...     ...      ...      ...         ...         ...        ...
# 99996    13       1        0        1           0           0  16.900003
# 99997    13       1        2        2           0           0  24.914742
# 99998    13       1        0        1           0           0  15.088801
# 99999    13       1        0        1           0           0  26.729368
# 100000   13       1        2        2           0           0   7.437753
#
#                Py         Pz     E    M         PT       Eta       Phi  \
# event
# 1        7.723918  38.588926  40.0  0.0  10.530658  2.009940  0.823413
# 2      -39.287148   0.796183  40.0  0.0  39.992075  0.019907 -1.758832
# 3       -1.670173  27.659378  40.0  0.0  28.895653  0.850795 -0.057832
# 4       36.260344  16.256256  40.0  0.0  36.547697  0.431299  1.696277
# 5       18.432058  12.520472  40.0  0.0  37.989969  0.323881  0.506572
# ...           ...        ...   ...  ...        ...       ...       ...
# 99996   -7.827427  35.399453  40.0  0.0  18.624680  1.398312 -0.433745
# 99997    2.568377  31.187483  40.0  0.0  25.046775  1.044572  0.102724
# 99998    7.045156  36.368858  40.0  0.0  16.652512  1.523014  0.436829
# 99999  -16.098346  25.027667  40.0  0.0  31.202819  0.734304 -0.542088
# 100000 -35.932776  15.922169  40.0  0.0  36.694476  0.421335 -1.366688
#
#         Rapidity  LifeTime  Spin   event  cos_theta
# event
# 1       2.009940       0.0   1.0       1   0.964723
# 2       0.019907       0.0  -1.0       2   0.019905
# 3       0.850795       0.0   1.0       3   0.691484
# 4       0.431299       0.0  -1.0       4   0.406406
# 5       0.323881       0.0  -1.0       5   0.313012
# ...          ...       ...   ...     ...        ...
# 99996   1.398312       0.0  -1.0   99996   0.884986
# 99997   1.044572       0.0  -1.0   99997   0.779687
# 99998   1.523014       0.0   1.0   99998   0.909221
# 99999   0.734304       0.0  -1.0   99999   0.625692
# 100000  0.421335       0.0   1.0  100000   0.398054
#
# [100000 rows x 19 columns]

# %%
# 80 GeV
cross_section = 3.512700e+01

# %%
n_events = len( df_sel )
print ( n_events )
weights = np.ones( n_events )
weights
# Out:
# 100000
# array([1., 1., 1., ..., 1., 1., 1.])

# %%
def plot_cos_theta( dfsel, weights, label='', ylabel='', bins=50, linestyle='solid' ):
    dfsel__ = dfsel
    label__ = label
    linestyle__ = linestyle
#     plt.hist( dfsel__[ 'cos_theta' ], histtype='step', bins=100, label=label__, linestyle=linestyle__ )
    plt.hist( dfsel__[ 'cos_theta' ], weights=weights, histtype='step', bins=50, label=label__, linestyle=linestyle__ )
    plt.xlabel( r"$\cos\theta$" )
    plt.ylabel( ylabel )

# %%
fig = plt.figure( figsize=(12,10) )
plot_cos_theta( df_sel, weights=weights, bins=50, ylabel="Número de eventos" )

# %%
print ( cross_section )
weights_sigma = np.ones( n_events ) * ( cross_section / n_events )
weights_sigma
# Out:
# 35.127
# array([0.00035127, 0.00035127, 0.00035127, ..., 0.00035127, 0.00035127,
#        0.00035127])

# %%
fig = plt.figure( figsize=(12,10) )
plot_cos_theta( df_sel, weights=weights_sigma, bins=50, ylabel=r"$\Delta \sigma_i\,(\rm{pb})$" )

# %% [markdown]
# ### Seção de choque *diferencial*

# %%
bins = 50

delta_cos_theta = ( 2. / bins )
print ( delta_cos_theta )

weights_binwidth = weights / delta_cos_theta
print ( weights_binwidth )

fig = plt.figure( figsize=(12,10) )
plot_cos_theta( df_sel, weights=weights_binwidth, bins=bins, ylabel=r"$\frac{\Delta \sigma_i}{\Delta(\cos\theta)} \approx \frac{d\sigma}{d\cos\theta} \,(\rm{pb})$" )
# Out:
# 0.04
# [0.00878175 0.00878175 0.00878175 ... 0.00878175 0.00878175 0.00878175]

# %% [markdown]
# ### Número de eventos esperados (para um valor de luminosidade/fluxo)

# %%
L = 100. # pb^{-1}
print ( "cross section = {} (pb)".format( cross_section ) )
print ( "L = {} (1/pb)".format( L ) )

N_esp = cross_section * L
print ( "N(esp.) = {:.2f}".format( N_esp ) )
# Out:
# cross section = 35.127 (pb)
# L = 100.0 (1/pb)
# N(esp.) = 3512.70

# %%
print ( cross_section )
weights_nexpected = np.ones( n_events ) * ( cross_section * L / n_events )
print ( weights_nexpected )

fig = plt.figure( figsize=(12,10) )
plot_cos_theta( df_sel, weights=weights_nexpected, bins=50, ylabel="Número esperado de eventos (L = {:.0f}{})".format( L , r"$\rm{pb}^{-1}$" ) )
# Out:
# 35.127
# [0.035127 0.035127 0.035127 ... 0.035127 0.035127 0.035127]
