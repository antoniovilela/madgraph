# %%
import sys
sys.path.insert(0,'/eos/home-a/antoniov/SWAN_projects/env/uproot-py39/lib/python3.9/site-packages')
print ( sys.path )
import uproot
import awkward as ak
import numpy as np
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
mpl.rcParams.update(
    {'font.size': 18,
     'font.family': 'sans-serif',
     'legend.fontsize': 14,
     'axes.labelsize': 22,
     'axes.labelpad': 8.0,
     'xtick.labelsize': 14,
     'ytick.labelsize': 14
    }
    )
# print ( mpl.rcParams )
# Out:
# ['/eos/home-a/antoniov/SWAN_projects/env/uproot-py39/lib/python3.9/site-packages', '/cvmfs/sft.cern.ch/lcg/releases/condor/8.9.11-f6d1a/x86_64-centos7-gcc11-opt/lib/python3', '/cvmfs/sft.cern.ch/lcg/views/LCG_103swan/x86_64-centos7-gcc11-opt/lib/python3.9/site-packages/itk', '/cvmfs/sft.cern.ch/lcg/views/LCG_103swan/x86_64-centos7-gcc11-opt/python', '/cvmfs/sft.cern.ch/lcg/views/LCG_103swan/x86_64-centos7-gcc11-opt/lib', '', '/cvmfs/sft.cern.ch/lcg/views/LCG_103swan/x86_64-centos7-gcc11-opt/lib/python3.9/site-packages', '/srv/dask/lib', '/cvmfs/sft.cern.ch/lcg/releases/Python/3.9.6-b0f98/x86_64-centos7-gcc8-opt/lib/python39.zip', '/cvmfs/sft.cern.ch/lcg/releases/Python/3.9.6-b0f98/x86_64-centos7-gcc8-opt/lib/python3.9', '/cvmfs/sft.cern.ch/lcg/releases/Python/3.9.6-b0f98/x86_64-centos7-gcc8-opt/lib/python3.9/lib-dynload', '/eos/home-a/antoniov/SWAN_projects/env/uproot-py39/lib/python3.9/site-packages', '/cvmfs/sft.cern.ch/lcg/views/LCG_103swan/x86_64-centos7-gcc11-opt/lib/python3.9/site-packages/IPython/extensions', '/scratch/antoniov/.ipython']

# %%
from read_lhe_uproot import *

# %%
# MadGraph

# pt_min = 90.
# pt_max = 1000.
#  === Results Summary for run: run_01 tag: tag_1 ===
#
#     Cross-section :   1.968e+06 +- 1971 pb
#     Nb of events :  50000

# pt_min = 1000.
# pt_max = 2000.
#  === Results Summary for run: run_02 tag: tag_1 ===
#
#     Cross-section :   9.533 +- 0.01089 pb
#     Nb of events :  50000

# pt_min = 2000.
# pt_max = 3000.
#  === Results Summary for run: run_03 tag: tag_1 ===
#
#     Cross-section :   0.04175 +- 4.908e-05 pb
#     Nb of events :  50000

# pt_min = 3000.
# pt_max = 4000.
#  === Results Summary for run: run_04 tag: tag_1 ===
#
#     Cross-section :   0.0003866 +- 4.96e-07 pb
#     Nb of events :  50000

# %%
dir__ = 'SM_pp_jj_13TeV'
path__ = 'data/{}/run_01/unweighted_events.root'.format( dir__ )
df_ptbin1 = read_lhe_uproot( path__ )
path__ = 'data/{}/run_02/unweighted_events.root'.format( dir__ )
df_ptbin2 = read_lhe_uproot( path__ )
path__ = 'data/{}/run_03/unweighted_events.root'.format( dir__ )
df_ptbin3 = read_lhe_uproot( path__ )
path__ = 'data/{}/run_04/unweighted_events.root'.format( dir__ )
df_ptbin4 = read_lhe_uproot( path__ )
# Out:
# ['Event', 'Event/Event.fUniqueID', 'Event/Event.fBits', 'Event/Event.Number', 'Event/Event.Nparticles', 'Event/Event.ProcessID', 'Event/Event.Weight', 'Event/Event.ScalePDF', 'Event/Event.CouplingQED', 'Event/Event.CouplingQCD', 'Event_size', 'Rwgt', 'Rwgt/Rwgt.fUniqueID', 'Rwgt/Rwgt.fBits', 'Rwgt/Rwgt.Weight', 'Rwgt_size', 'Particle', 'Particle/Particle.fUniqueID', 'Particle/Particle.fBits', 'Particle/Particle.PID', 'Particle/Particle.Status', 'Particle/Particle.Mother1', 'Particle/Particle.Mother2', 'Particle/Particle.ColorLine1', 'Particle/Particle.ColorLine2', 'Particle/Particle.Px', 'Particle/Particle.Py', 'Particle/Particle.Pz', 'Particle/Particle.E', 'Particle/Particle.M', 'Particle/Particle.PT', 'Particle/Particle.Eta', 'Particle/Particle.Phi', 'Particle/Particle.Rapidity', 'Particle/Particle.LifeTime', 'Particle/Particle.Spin', 'Particle_size']
# Number of events: 50000
# ['Event', 'Event/Event.fUniqueID', 'Event/Event.fBits', 'Event/Event.Number', 'Event/Event.Nparticles', 'Event/Event.ProcessID', 'Event/Event.Weight', 'Event/Event.ScalePDF', 'Event/Event.CouplingQED', 'Event/Event.CouplingQCD', 'Event_size', 'Rwgt', 'Rwgt/Rwgt.fUniqueID', 'Rwgt/Rwgt.fBits', 'Rwgt/Rwgt.Weight', 'Rwgt_size', 'Particle', 'Particle/Particle.fUniqueID', 'Particle/Particle.fBits', 'Particle/Particle.PID', 'Particle/Particle.Status', 'Particle/Particle.Mother1', 'Particle/Particle.Mother2', 'Particle/Particle.ColorLine1', 'Particle/Particle.ColorLine2', 'Particle/Particle.Px', 'Particle/Particle.Py', 'Particle/Particle.Pz', 'Particle/Particle.E', 'Particle/Particle.M', 'Particle/Particle.PT', 'Particle/Particle.Eta', 'Particle/Particle.Phi', 'Particle/Particle.Rapidity', 'Particle/Particle.LifeTime', 'Particle/Particle.Spin', 'Particle_size']
# Number of events: 50000
# ['Event', 'Event/Event.fUniqueID', 'Event/Event.fBits', 'Event/Event.Number', 'Event/Event.Nparticles', 'Event/Event.ProcessID', 'Event/Event.Weight', 'Event/Event.ScalePDF', 'Event/Event.CouplingQED', 'Event/Event.CouplingQCD', 'Event_size', 'Rwgt', 'Rwgt/Rwgt.fUniqueID', 'Rwgt/Rwgt.fBits', 'Rwgt/Rwgt.Weight', 'Rwgt_size', 'Particle', 'Particle/Particle.fUniqueID', 'Particle/Particle.fBits', 'Particle/Particle.PID', 'Particle/Particle.Status', 'Particle/Particle.Mother1', 'Particle/Particle.Mother2', 'Particle/Particle.ColorLine1', 'Particle/Particle.ColorLine2', 'Particle/Particle.Px', 'Particle/Particle.Py', 'Particle/Particle.Pz', 'Particle/Particle.E', 'Particle/Particle.M', 'Particle/Particle.PT', 'Particle/Particle.Eta', 'Particle/Particle.Phi', 'Particle/Particle.Rapidity', 'Particle/Particle.LifeTime', 'Particle/Particle.Spin', 'Particle_size']
# Number of events: 50000
# ['Event', 'Event/Event.fUniqueID', 'Event/Event.fBits', 'Event/Event.Number', 'Event/Event.Nparticles', 'Event/Event.ProcessID', 'Event/Event.Weight', 'Event/Event.ScalePDF', 'Event/Event.CouplingQED', 'Event/Event.CouplingQCD', 'Event_size', 'Rwgt', 'Rwgt/Rwgt.fUniqueID', 'Rwgt/Rwgt.fBits', 'Rwgt/Rwgt.Weight', 'Rwgt_size', 'Particle', 'Particle/Particle.fUniqueID', 'Particle/Particle.fBits', 'Particle/Particle.PID', 'Particle/Particle.Status', 'Particle/Particle.Mother1', 'Particle/Particle.Mother2', 'Particle/Particle.ColorLine1', 'Particle/Particle.ColorLine2', 'Particle/Particle.Px', 'Particle/Particle.Py', 'Particle/Particle.Pz', 'Particle/Particle.E', 'Particle/Particle.M', 'Particle/Particle.PT', 'Particle/Particle.Eta', 'Particle/Particle.Phi', 'Particle/Particle.Rapidity', 'Particle/Particle.LifeTime', 'Particle/Particle.Spin', 'Particle_size']
# Number of events: 50000

# %%
df_ptbins = {
    'ptbin1': df_ptbin1,
    'ptbin2': df_ptbin2,
    'ptbin3': df_ptbin3,
    'ptbin4': df_ptbin4
}

# %%
df_ptbins[ 'ptbin1' ]
# Out:
#        PID  Status  Mother1  Mother2  ColorLine1  ColorLine2          Px  \
# event
# 1       21      -1       -1       -1         502         501    0.000000
# 1       21      -1       -1       -1         503         502   -0.000000
# 1       21       1        0        1         503         504   75.360739
# 1       21       1        0        1         504         501  -75.360739
# 2       -3      -1       -1       -1           0         501   -0.000000
# ...    ...     ...      ...      ...         ...         ...         ...
# 49999    2       1        0        1         501           0  154.240161
# 50000    2      -1       -1       -1         503           0   -0.000000
# 50000   21      -1       -1       -1         501         502    0.000000
# 50000   21       1        0        1         503         502   18.901744
# 50000    2       1        0        1         501           0  -18.901744
#
#                Py          Pz           E    M          PT         Eta  \
# event
# 1        0.000000  583.738568  583.738568  0.0    0.000000  999.900000
# 1       -0.000000  -60.255185   60.255185  0.0    0.000000 -999.900000
# 1      -53.253656  -18.581937   94.130129  0.0   92.277802   -0.200033
# 1       53.253656  542.065321  549.863624  0.0   92.277802    2.470897
# 2        0.000000  380.126176  380.126176  0.0    0.000000  999.900000
# ...           ...         ...         ...  ...         ...         ...
# 49999    0.971495  131.530367  202.709666  0.0  154.243221    0.773329
# 50000    0.000000  750.830551  750.830551  0.0    0.000000  999.900000
# 50000   -0.000000  -76.566358   76.566358  0.0    0.000000 -999.900000
# 50000  238.944128  347.597360  422.226831  0.0  239.690576    1.166813
# 50000 -238.944128  326.666833  405.170078  0.0  239.690576    1.116209
#
#             Phi    Rapidity  LifeTime  Spin  event
# event
# 1      0.000000  999.900000       0.0  -1.0      1
# 1      0.000000 -999.900000       0.0  -1.0      1
# 1     -0.615175   -0.200033       0.0  -1.0      1
# 1      2.526418    2.470897       0.0  -1.0      1
# 2      0.000000  999.900000       0.0  -1.0      2
# ...         ...         ...       ...   ...    ...
# 49999  0.006299    0.773329       0.0  -1.0  49999
# 50000  0.000000  999.900000       0.0   1.0  50000
# 50000  0.000000 -999.900000       0.0  -1.0  50000
# 50000  1.491855    1.166813       0.0  -1.0  50000
# 50000 -1.649737    1.116209       0.0   1.0  50000
#
# [200000 rows x 18 columns]

# %%
cross_section = { # pb
    'ptbin1': 1.968e+06,
    'ptbin2': 9.533,
    'ptbin3': 0.04175,
    'ptbin4': 0.0003866
}

n_events = {
    'ptbin1': 50000,
    'ptbin2': 50000,
    'ptbin3': 50000,
    'ptbin4': 50000
}

norm = {}
for key__ in cross_section:
    norm[ key__ ] = cross_section[ key__ ] / n_events[ key__ ]

norm
# Out:
# {'ptbin1': 39.36,
#  'ptbin2': 0.00019066,
#  'ptbin3': 8.35e-07,
#  'ptbin4': 7.732000000000001e-09}

# %%
bins = [  97. , 133. , 174. , 220. , 272. , 330. , 395. , 468. , 548. , 638. , 737. , 846. ,
         967. , 1101. , 1248. , 1410. , 1588. , 1784. , 2000. , 2238. , 2500. , 2787. , 3103. ]
bins = np.array( bins )

bin_centres = ( bins[:-1] + bins[1:] ) / 2

bin_widths = ( bins[1:] - bins[:-1] )

print ( bins ) 
print ( bin_centres )
print ( bin_widths )
# Out:
# [  97.  133.  174.  220.  272.  330.  395.  468.  548.  638.  737.  846.
#   967. 1101. 1248. 1410. 1588. 1784. 2000. 2238. 2500. 2787. 3103.]
# [ 115.   153.5  197.   246.   301.   362.5  431.5  508.   593.   687.5
#   791.5  906.5 1034.  1174.5 1329.  1499.  1686.  1892.  2119.  2369.
#  2643.5 2945. ]
# [ 36.  41.  46.  52.  58.  65.  73.  80.  90.  99. 109. 121. 134. 147.
#  162. 178. 196. 216. 238. 262. 287. 316.]

# %%
def process_select_data( df ):
    df__ = df
    selection__ = ( ( df__.Status == 1 ) & ( df__.PT >= bins[0] ) & ( df__.PT < bins[-1] ) )
    df_sel__ = df__[ selection__ ]
    return df_sel__

# %%
ybins = np.array( [0., 0.5, 1.0, 1.5, 2.0 ] )
ymin = ybins[:-1]
ymax = ybins[1:]
print ( ymin )
print ( ymax )
# Out:
# [0.  0.5 1.  1.5]
# [0.5 1.  1.5 2. ]

# %%
histos = {}
for key__ in df_ptbins:
    df_ptbins[ key__ ] = process_select_data( df_ptbins[ key__ ] )
    df__ = df_ptbins[ key__ ]
    for idx_y__ in range( len(ymin) ):
        msk__ = ( ( np.abs( df__.Rapidity ) >= ymin[ idx_y__ ] ) & ( np.abs( df__.Rapidity ) < ymax[ idx_y__ ] ) )
        counts__, __bins = np.histogram( df__.PT[ msk__ ], bins=bins )
        histos_key__ = 'ybin'+str(idx_y__+1)
        if histos_key__ not in histos.keys():
            histos[ histos_key__ ] = ( counts__ * norm[ key__ ]  )
        else:
            histos[ histos_key__ ] += ( counts__ * norm[ key__ ] )
histos
# Out:
# {'ybin1': array([4.27646400e+05, 1.07334720e+05, 3.24326400e+04, 1.16899200e+04,
#         4.25088000e+03, 1.45632000e+03, 4.72320000e+02, 4.32960000e+02,
#         7.87200000e+01, 0.00000000e+00, 3.93600000e+01, 0.00000000e+00,
#         3.75123550e+00, 2.53863790e+00, 1.14148142e+00, 4.85801680e-01,
#         2.17161740e-01, 9.53300000e-02, 3.42575450e-02, 1.23772050e-02,
#         4.04474000e-03, 1.25903297e-03]),
#  'ybin2': array([4.00330560e+05, 1.04422080e+05, 3.22752000e+04, 1.22803200e+04,
#         3.58176000e+03, 1.84992000e+03, 5.90400000e+02, 2.36160000e+02,
#         7.87200000e+01, 1.18080000e+02, 7.87200000e+01, 0.00000000e+00,
#         3.05666112e+00, 2.01470422e+00, 8.64071120e-01, 3.71596340e-01,
#         1.54625260e-01, 5.77699800e-02, 1.92943450e-02, 5.99530000e-03,
#         1.79024000e-03, 3.97333036e-04]),
#  'ybin3': array([3.66402240e+05, 9.36374400e+04, 2.74732800e+04, 9.13152000e+03,
#         3.58176000e+03, 9.05280000e+02, 3.54240000e+02, 1.18080000e+02,
#         3.93600000e+01, 7.87200000e+01, 3.93600000e+01, 0.00000000e+00,
#         1.79620786e+00, 1.05244320e+00, 4.11825600e-01, 1.39181800e-01,
#         4.80463200e-02, 1.60154400e-02, 3.47026000e-03, 7.43985000e-04,
#         1.28590000e-04, 1.61279440e-05]),
#  'ybin4': array([3.1428960e+05, 7.5610560e+04, 2.1451200e+04, 6.7699200e+03,
#         2.7552000e+03, 8.6592000e+02, 4.7232000e+02, 7.8720000e+01,
#         0.0000000e+00, 3.9360000e+01, 0.0000000e+00, 0.0000000e+00,
#         5.1344738e-01, 2.2707606e-01, 6.2536480e-02, 1.2392900e-02,
#         3.0505600e-03, 1.9066000e-04, 2.1710000e-05, 0.0000000e+00,
#         0.0000000e+00, 0.0000000e+00])}

# %%
fig = plt.figure( figsize=(12,10) )

factors = {
    'ybin1': 1e+00,
    'ybin2': 1e-01,
    'ybin3': 1e-02,
    'ybin4': 1e-03,
}
labels = {
    'ybin1': r"$|y| < 0.5 \,(\times 10^0)$",
    'ybin2': r"$0.5 < |y| < 1.0 \,(\times 10^{-1})$",
    'ybin3': r"$1.0 < |y| < 1.5 \,(\times 10^{-2})$",
    'ybin4': r"$1.5 < |y| < 2.0 \,(\times 10^{-3})$",
}

for key__ in histos:
    plt.hist( bin_centres, weights=( ( histos[ key__ ] / bin_widths / 0.5 ) * factors[ key__ ] ), label=labels[ key__ ], histtype='step' )

plt.xlabel( r'jet $p_T\,(\rm{GeV})$' )
plt.ylabel( r'$d^2\sigma/dp_T dy \,(\rm{pb}/\rm{GeV})$' )

plt.xlim( 1e+02, 3e+03 )
plt.ylim( 2e-08, 5e+04 )
plt.xscale( 'log' )
plt.yscale( 'log' )
plt.legend( loc='best' )

# %%
df_ptbins[ 'ptbin1' ]
# Out:
#        PID  Status  Mother1  Mother2  ColorLine1  ColorLine2          Px  \
# event
# 3       21       1        0        1         503         502 -156.534269
# 3       21       1        0        1         504         501  156.534269
# 5       21       1        0        1         503         502   12.729478
# 5       21       1        0        1         504         501  -12.729478
# 6       21       1        0        1         503         501   13.627557
# ...    ...     ...      ...      ...         ...         ...         ...
# 49997    2       1        0        1         501           0  -99.149726
# 49999   21       1        0        1         503         502 -154.240161
# 49999    2       1        0        1         501           0  154.240161
# 50000   21       1        0        1         503         502   18.901744
# 50000    2       1        0        1         501           0  -18.901744
#
#                Py          Pz           E    M          PT       Eta  \
# event
# 3       41.398609 -217.971692  271.529889  0.0  161.916096 -1.106309
# 3      -41.398609  147.279479  218.879115  0.0  161.916096  0.815988
# 5     -152.919069 -430.285278  456.827868  0.0  153.447976 -1.754611
# 5      152.919069  372.502454  402.870152  0.0  153.447976  1.619982
# 6     -127.432683   14.672282  128.996414  0.0  128.159272  0.114236
# ...           ...         ...         ...  ...         ...       ...
# 49997   -4.508129  962.899189  968.000950  0.0   99.252160  2.968078
# 49999   -0.971495  379.676327  409.811035  0.0  154.243221  1.632853
# 49999    0.971495  131.530367  202.709666  0.0  154.243221  0.773329
# 50000  238.944128  347.597360  422.226831  0.0  239.690576  1.166813
# 50000 -238.944128  326.666833  405.170078  0.0  239.690576  1.116209
#
#             Phi  Rapidity  LifeTime  Spin  event
# event
# 3      2.883042 -1.106309       0.0  -1.0      3
# 3     -0.258550  0.815988       0.0  -1.0      3
# 5     -1.487745 -1.754611       0.0   1.0      5
# 5      1.653848  1.619982       0.0   1.0      5
# 6     -1.464262  0.114236       0.0  -1.0      6
# ...         ...       ...       ...   ...    ...
# 49997 -3.096156  2.968078       0.0   1.0  49997
# 49999 -3.135294  1.632853       0.0  -1.0  49999
# 49999  0.006299  0.773329       0.0  -1.0  49999
# 50000  1.491855  1.166813       0.0  -1.0  50000
# 50000 -1.649737  1.116209       0.0   1.0  50000
#
# [72784 rows x 18 columns]
